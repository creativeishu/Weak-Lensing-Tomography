# %%
# %matplotlib inline 
from WLlib import WeakLensingLib as WL

# %%
NumberOfBins=3
zm=1.2

zmin = 0.2
zmax = 5.0
zdim = 100

kmin = 0.04
kmax = 1.3
kdim = 1000

lmin = 10
lmax = 10000
ldim = 20

omegaM = 0.279 
sigma8 = 0.817
h = 0.701
ns = 0.96 
omegaB = 0.0462 
w0 = -1.0
wa = 0.0 
omegaR = 0.0 
omegaK = 0.0

CosmoParams=[omegaM, sigma8, h, ns, omegaB, w0, wa, omegaR, omegaK]
mode='custom'
nskip = 5

# %%
obj = WL(NumberOfBins, zm, zmin, zmax, zdim, kmin, kmax, kdim, lmin, lmax, ldim, CosmoParams, nskip)
ell, C_nonlinear = obj.compute_cell(mode)
# Out:
# ==========================================================
# Reading files from:  /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/
# Skipping every 4 files
# ==========================================================
# 3 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.0507.pk
# 8 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.1004.pk
# 13 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.1503.pk
# 18 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.2002.pk
# 23 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.2503.pk
# 28 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.3004.pk
# 33 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.3501.pk
# 38 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.4007.pk
# 43 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.4501.pk
# 48 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.5004.pk
# 53 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.5509.pk
# 58 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.6007.pk
# 63 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.6502.pk
# 68 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.7002.pk
# 73 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.7509.pk
# 78 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.8009.pk
# 83 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.8506.pk
# 88 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.9009.pk
# 93 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=0.9503.pk
# 98 /Users/mohammed/Dropbox/fermilabwork/with_gnedin/sim1/PK/matter_power_a=1.0004.pk
# ==========================================================
# Total number of files used:  20
# ==========================================================

# %%
obj.plot_dist()
obj.plot_q()
obj.plot_pk()
obj.plot_cell()
obj.plot_cell_grid()
