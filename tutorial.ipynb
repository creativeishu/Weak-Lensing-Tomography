# %%
# %matplotlib inline 
from WLlib import WeakLensingLib as WL

# %%
NumberOfBins=4
zm=1.2

zmin = 0.2
zmax = 5.0
zdim = 100

kmin = 0.001
kmax = 100
kdim = 1000

lmin = 10
lmax = 50000
ldim = 40

omegaM = 0.279 
sigma8 = 0.817
h = 0.701
ns = 0.96 
omegaB = 0.0462 
w0 = -1.0
wa = 0.0 
omegaR = 0.0 
omegaK = 0.0

CosmoParams=[omegaM, sigma8, h, ns, omegaB, w0, wa, omegaR, omegaK]
mode='nonlinear'

# %%
obj = WL(NumberOfBins, zm, zmin, zmax, zdim, kmin, kmax, kdim, lmin, lmax, ldim, CosmoParams)

# %%
ell, C_nonlinear = obj.compute_cell(mode)
# Out:
# Note: redshifts have been re-sorted (earliest first)
# WARNING:root:get_matter_power_spectrum using larger k_max than input parameter Transfer.kmax

# %%
obj.plot_dist()
obj.plot_q()
obj.plot_pk()
obj.plot_cell()
obj.plot_cell_grid()
